# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt

# %%
csv_path1 = "muniestbycounty_byyr.csv"
population_df=pd.read_csv(csv_path1,encoding="utf-8",sep=';')
population_df.head()
# Out:
#      County       Municipality          Year  Population
# 0  Alamance   Burlington(Part)  July 1, 2018       52866
# 1  Alamance  Gibsonville(Part)  July 1, 2018        3687
# 2  Alamance             Graham  July 1, 2018       15136
# 3     Anson             Morven  July 1, 2018         486
# 4      Ashe     Unincorporated  July 1, 2018       24580

# %%
csv_path2 = "uszips.csv"
zip_df = pd.read_csv(csv_path2,encoding="utf-8")
zip_df.head()
# Out:
#    zip       lat       lng       city state_id   state_name  zcta  \
# 0  601  18.18004 -66.75218   Adjuntas       PR  Puerto Rico  True
# 1  602  18.36073 -67.17517     Aguada       PR  Puerto Rico  True
# 2  603  18.45439 -67.12202  Aguadilla       PR  Puerto Rico  True
# 3  606  18.16724 -66.93828    Maricao       PR  Puerto Rico  True
# 4  610  18.29032 -67.12243     Anasco       PR  Puerto Rico  True
#
#    parent_zcta  population  density  county_fips county_name  \
# 0          NaN       17242    111.4        72001    Adjuntas
# 1          NaN       38442    523.5        72003      Aguada
# 2          NaN       48814    667.9        72005   Aguadilla
# 3          NaN        6437     60.4        72093     Maricao
# 4          NaN       27073    312.0        72011      Añasco
#
#                               county_weights             county_names_all  \
# 0               {'72001':99.43,'72141':0.57}              Adjuntas|Utuado
# ...

# %%
new_zip=zip_df[["zip","lat","lng","city","state_name","county_name"]]
new_zip.head()
# Out:
#    zip       lat       lng       city   state_name county_name
# 0  601  18.18004 -66.75218   Adjuntas  Puerto Rico    Adjuntas
# 1  602  18.36073 -67.17517     Aguada  Puerto Rico      Aguada
# 2  603  18.45439 -67.12202  Aguadilla  Puerto Rico   Aguadilla
# 3  606  18.16724 -66.93828    Maricao  Puerto Rico     Maricao
# 4  610  18.29032 -67.12243     Anasco  Puerto Rico      Añasco

# %%
nc_df = new_zip.loc[new_zip["state_name"] == "North Carolina"]
nc_df= nc_df.rename(columns={"county_name":"County"})
nc_df.head()
# Out:
#         zip       lat       lng          city      state_name   County
# 8335  27006  35.94454 -80.43766       Advance  North Carolina    Davie
# 8336  27007  36.38733 -80.59249        Ararat  North Carolina    Surry
# 8337  27009  36.23307 -80.07610  Belews Creek  North Carolina  Forsyth
# 8338  27011  36.21560 -80.69667     Boonville  North Carolina   Yadkin
# 8339  27012  36.00410 -80.37582      Clemmons  North Carolina  Forsyth

# %%
census_df=pd.merge(nc_df,population_df,on='County')
census_df.head()
# Out:
#      zip       lat       lng       city      state_name County  \
# 0  27006  35.94454 -80.43766    Advance  North Carolina  Davie
# 1  27006  35.94454 -80.43766    Advance  North Carolina  Davie
# 2  27006  35.94454 -80.43766    Advance  North Carolina  Davie
# 3  27006  35.94454 -80.43766    Advance  North Carolina  Davie
# 4  27014  35.81209 -80.55515  Cooleemee  North Carolina  Davie
#
#      Municipality          Year  Population
# 0      Mocksville  July 1, 2018        5425
# 1  Unincorporated  July 1, 2018       33913
# 2     Bermuda Run  July 1, 2018        2665
# 3       Cooleemee  July 1, 2018         973
# 4      Mocksville  July 1, 2018        5425
