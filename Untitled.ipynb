# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
from scipy import stats

# %%
def regression (xnot,xxx,yyy):
    yval = [] 
    xval = [] 
    totdays = len(xxx) -2
    for days in range(1,totdays):
        xval.append(xxx[days])
        if yyy[days]>1:
            yval.append(np.log(yyy[days]))
        else:
            yval.append(1)
    (slope, intercept, r, a, b)=stats.linregress(xval, yval)
    return slope,r*r

# %%
data = pd.read_csv("https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv")
df = pd.DataFrame(data)
df.head()
# Out:
#          date     county       state     fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061.0      1       0
# 1  2020-01-22  Snohomish  Washington  53061.0      1       0
# 2  2020-01-23  Snohomish  Washington  53061.0      1       0
# 3  2020-01-24       Cook    Illinois  17031.0      1       0
# 4  2020-01-24  Snohomish  Washington  53061.0      1       0

# %%
df['date'] = pd.to_datetime(df['date'])
df.head()
counties = df['county'].value_counts()
states = df['state'].value_counts()
wake = df.loc[(df['state']=='North Carolina')& (df['county']=='Mecklenburg')]
wake.head(35)
# Out:
#             date       county           state     fips  cases  deaths
# 1532  2020-03-12  Mecklenburg  North Carolina  37119.0      2       0
# 1826  2020-03-13  Mecklenburg  North Carolina  37119.0      2       0
# 2180  2020-03-14  Mecklenburg  North Carolina  37119.0      2       0
# 2592  2020-03-15  Mecklenburg  North Carolina  37119.0      4       0
# 3054  2020-03-16  Mecklenburg  North Carolina  37119.0      4       0
# 3574  2020-03-17  Mecklenburg  North Carolina  37119.0      7       0
# 4181  2020-03-18  Mecklenburg  North Carolina  37119.0     11       0
# 4912  2020-03-19  Mecklenburg  North Carolina  37119.0     13       0
# 5766  2020-03-20  Mecklenburg  North Carolina  37119.0     28       0
# 6763  2020-03-21  Mecklenburg  North Carolina  37119.0     41       0
# 7865  2020-03-22  Mecklenburg  North Carolina  37119.0     66       0
# 9066  2020-03-23  Mecklenburg  North Carolina  37119.0     80       0
# 10379 2020-03-24  Mecklenburg  North Carolina  37119.0    104       0
# 11828 2020-03-25  Mecklenburg  North Carolina  37119.0    170       0
# 13441 2020-03-26  Mecklenburg  North Carolina  37119.0    181       0
# 15186 2020-03-27  Mecklenburg  North Carolina  37119.0    218       0
# 17028 2020-03-28  Mecklenburg  North Carolina  37119.0    299       0
# 18973 2020-03-29  Mecklenburg  North Carolina  37119.0    336       1
# 21023 2020-03-30  Mecklenburg  North Carolina  37119.0    382       1
# 23168 2020-03-31  Mecklenburg  North Carolina  37119.0    420       1
# 25372 2020-04-01  Mecklenburg  North Carolina  37119.0    444       2
# 27636 2020-04-02  Mecklenburg  North Carolina  37119.0    495       2
# 29962 2020-04-03  Mecklenburg  North Carolina  37119.0    564       2
# 32351 2020-04-04  Mecklenburg  North Carolina  37119.0    635       4
# 34784 2020-04-05  Mecklenburg  North Carolina  37119.0    664       6
# 37257 2020-04-06  Mecklenburg  North Carolina  37119.0    733       7
# 39770 2020-04-07  Mecklenburg  North Carolina  37119.0    810       8
# 42323 2020-04-08  Mecklenburg  North Carolina  37119.0    830      10
# 44900 2020-04-09  Mecklenburg  North Carolina  37119.0    861      10

# %%
exponential={}
for st in states.index:
    state = df.loc[df['state']==st]
    counties = state['county'].value_counts()
    exponential.update( {st : {}} )
    for cnt in counties.index:
        county = state.loc[(df['county'] == cnt)]
        yprev = 0
        exponential[st].update({cnt:{}})
        exponential[st][cnt].update( {'xval' : []})
        exponential[st][cnt].update({'delta' :[]})
#         exponential[st][cnt].update({'date' :[]})
        days=0
        for y,z in county.iterrows(): 
            ycur = z['cases']
            dif = ycur - yprev
            exponential[st][cnt]['delta'].append(dif)
            exponential[st][cnt]['xval'].append(days)
#             exponential[st][cnt]['date'].append(z['date'])
            days=days+1
            yprev = ycur

# %%
for st in states.index:
    test = exponential[st]
    for cnt in test:
#     print(f'processing county {cnt}.')
#     print(f'X Val:{len(test[cnt]["xval"])} ')
        test[cnt].update({'delta_cln':[0]})
        if len(test[cnt]['delta']) > 2:
            for x in np.arange(1,len(test[cnt]['delta'])-1,1):
                test[cnt]['delta_cln'].append((test[cnt]['delta'][x-1]+test[cnt]['delta'][x]+test[cnt]['delta'][x+1])/3)
            test[cnt]['delta_cln'].append(test[cnt]['delta'][x+1])

# %%
for st in states.index:
    test = exponential[st]
    for cnt in test:
        test[cnt].update({'delta_cln2':[0]})
        if len(test[cnt]['delta']) > 2:
            for x in np.arange(1,len(test[cnt]['delta_cln'])-1,1):
                test[cnt]['delta_cln2'].append((test[cnt]['delta_cln'][x-1]+test[cnt]['delta_cln'][x]+test[cnt]['delta_cln'][x+1])/3)
            test[cnt]['delta_cln2'].append(test[cnt]['delta_cln'][x+1])

# %%
for st in states.index:
    test = exponential[st]
    for cnt in test:
        test[cnt].update({'delta_cln3':[0]})
        if len(test[cnt]['delta']) > 2:
            for x in np.arange(1,len(test[cnt]['delta_cln2'])-1,1):
                test[cnt]['delta_cln3'].append((test[cnt]['delta_cln2'][x-1]+test[cnt]['delta_cln2'][x]+test[cnt]['delta_cln2'][x+1])/3)
            test[cnt]['delta_cln3'].append(test[cnt]['delta_cln'][x+1])

# %%
county_tau = {'State':[],'County':[],'First Doubling':[], 'Last Delta':[],
              'Inv Tau':[],'Tau':[],'R Squared':[]}
for st in states.index:
    test = exponential[st]
    for cnt in test:
        day=0
        test2 = test[cnt]
        for x in np.arange(1, len(test2['delta_cln3']),1):
            if test2['delta_cln3'][x]>4:
                day = x-1
                invtau,rr = regression(day,test2['xval'],test2['delta_cln3']) 
                county_tau['State'].append(st)
                county_tau['County'].append(cnt)
                county_tau['First Doubling'].append(day)
                county_tau['Last Delta'].append(test2['delta'][len(test2['delta_cln3'])-1])
                county_tau['Inv Tau'].append(invtau)
                if invtau != 0:
                    county_tau['Tau'].append(1/invtau)
                else:
                    county_tau['Tau'].append(0)
                county_tau['R Squared'].append(rr)
                break
# Out:
# C:\Users\littl\Anaconda3\envs\PythonData\lib\site-packages\scipy\stats\_stats_mstats_common.py:130: RuntimeWarning: invalid value encountered in double_scalars
#   slope = r_num / ssxm
# C:\Users\littl\Anaconda3\envs\PythonData\lib\site-packages\scipy\stats\_stats_mstats_common.py:140: RuntimeWarning: invalid value encountered in sqrt
#   t = r * np.sqrt(df / ((1.0 - r + TINY)*(1.0 + r + TINY)))
# C:\Users\littl\Anaconda3\envs\PythonData\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# C:\Users\littl\Anaconda3\envs\PythonData\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# C:\Users\littl\Anaconda3\envs\PythonData\lib\site-packages\scipy\stats\_distn_infrastructure.py:1912: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# C:\Users\littl\Anaconda3\envs\PythonData\lib\site-packages\scipy\stats\_stats_mstats_common.py:142: RuntimeWarning: invalid value encountered in double_scalars
#   sterrest = np.sqrt((1 - r**2) * ssym / ssxm / df)

# %%
df2=pd.DataFrame(county_tau)
df2=df2.sort_values('Inv Tau', ascending =False)
df3 = df2.loc[df2['Inv Tau']>0]
df2.head(40)
df2.to_csv('Countyspreaddata.csv')

# %%
df3.plot('Days In','Inv Tau', kind ='scatter')

# %%
state = 'Florida'
test =exponential[state]
for x in test:
     if len(test[x]['delta']) >2:
            plt.plot(test[x]['xval'],test[x]['delta'])
plt.show()

# %%
for x in test:
     if len(test[x]['delta']) >2:
            plt.plot(test[x]['xval'],test[x]['delta_cln'])
plt.show()

# %%
for x in test:
     if len(test[x]['delta']) >2:
            plt.plot(test[x]['xval'],test[x]['delta_cln2'])
plt.show()

# %%
for x in test:
     if len(test[x]['delta']) >2:
            plt.plot(test[x]['xval'],test[x]['delta_cln3'])
plt.show()

# %%
import keyboard
import time
for x in test:
    print(f'{x} County')
    df4 = df2.loc[(df2['County']==x)&(df2['State']==state)]
    print(df4)
    plt.plot(test[x]['xval'],test[x]['delta_cln3'])
    plt.show()
#     time.sleep(5)
# Out:
# Hillsborough County
#        State        County  First Doubling  Last Delta   Inv Tau       Tau  \
# 254  Florida  Hillsborough              16          26  0.104273  9.590211
#
#      R Squared
# 254   0.854068
# Manatee County
#        State   County  First Doubling  Last Delta   Inv Tau        Tau  \
# 255  Florida  Manatee              26           7  0.051411  19.451023
#
#      R Squared
# 255   0.487405
# Santa Rosa County
#        State      County  First Doubling  Last Delta   Inv Tau        Tau  \
# 256  Florida  Santa Rosa              22          26  0.021603  46.289939
#
#      R Squared
# 256     0.2651
# Broward County
#        State   County  First Doubling  Last Delta   Inv Tau       Tau  \
# 257  Florida  Broward               5         115  0.157163  6.362812
#
#      R Squared
# 257    0.90727
# Lee County
#        State County  First Doubling  Last Delta   Inv Tau      Tau  R Squared
# 258  Florida    Lee              14          46  0.116247  8.60236   0.829498
# Okaloosa County
#        State    County  First Doubling  Last Delta   Inv Tau        Tau  \
# 259  Florida  Okaloosa              23           5  0.022271  44.900653
#
#      R Squared
# 259   0.377053
# Charlotte County
#        State     County  First Doubling  Last Delta   Inv Tau        Tau  \
# 260  Florida  Charlotte              23           5  0.028783  34.743005
#
#      R Squared
# 260   0.453645
# Volusia County
#        State   County  First Doubling  Last Delta   Inv Tau        Tau  \
# 261  Florida  Volusia              16          14  0.072735  13.748586
#
#      R Squared
# 261   0.680604
# Collier County
#        State   County  First Doubling  Last Delta   Inv Tau        Tau  \
# 262  Florida  Collier               8          21  0.097027  10.306362
#
#      R Squared
# 262   0.864517
# Alachua County
#        State   County  First Doubling  Last Delta   Inv Tau       Tau  \
# 263  Florida  Alachua               9          10  0.049803  20.07928
#
#      R Squared
# 263   0.737291
# Pasco County
#        State County  First Doubling  Last Delta   Inv Tau        Tau  \
# 264  Florida  Pasco              16          12  0.066577  15.020132
#
#      R Squared
# 264   0.698503
# Nassau County
# Empty DataFrame
# Columns: [State, County, First Doubling, Last Delta, Inv Tau, Tau, R Squared]
# Index: []
# Pinellas County
#        State    County  First Doubling  Last Delta   Inv Tau       Tau  \
# 265  Florida  Pinellas               7          27  0.111097  9.001137
#
#      R Squared
# 265   0.833631
# St. Johns County
#        State     County  First Doubling  Last Delta   Inv Tau        Tau  \
# 266  Florida  St. Johns              11           7  0.070349  14.214926
#
#      R Squared
# 266   0.764379
# Miami-Dade County
#        State      County  First Doubling  Last Delta   Inv Tau       Tau  \
# 267  Florida  Miami-Dade               2         437  0.208394  4.798606
#
#      R Squared
# 267   0.909334
# Palm Beach County
#        State      County  First Doubling  Last Delta   Inv Tau       Tau  \
# 268  Florida  Palm Beach               4         109  0.172969  5.781371
#
#      R Squared
# 268   0.871802
# Sarasota County
#        State    County  First Doubling  Last Delta   Inv Tau        Tau  \
# 269  Florida  Sarasota               9          17  0.088371  11.315891
#
#      R Squared
# 269   0.871149
# Clay County
#        State County  First Doubling  Last Delta   Inv Tau        Tau  \
# 270  Florida   Clay              15          11  0.050168  19.932879
#
#      R Squared
# 270   0.683075
# Seminole County
#        State    County  First Doubling  Last Delta   Inv Tau        Tau  \
# 271  Florida  Seminole              11          11  0.096374  10.376226
#
#      R Squared
# 271   0.782749
# Duval County
#        State County  First Doubling  Last Delta   Inv Tau       Tau  R Squared
# 272  Florida  Duval               7          38  0.151863  6.584877    0.95128
# Orange County
#        State  County  First Doubling  Last Delta   Inv Tau      Tau  R Squared
# 273  Florida  Orange               4          36  0.161587  6.18862   0.832948
# Osceola County
#        State   County  First Doubling  Last Delta   Inv Tau       Tau  \
# 274  Florida  Osceola              10          18  0.120089  8.327157
#
#      R Squared
# 274   0.875503
# Citrus County
#        State  County  First Doubling  Last Delta   Inv Tau        Tau  \
# 275  Florida  Citrus              18           3  0.037309  26.803193
#
#      R Squared
# 275   0.294126
# Baker County
# Empty DataFrame
# Columns: [State, County, First Doubling, Last Delta, Inv Tau, Tau, R Squared]
# Index: []
# Escambia County
#        State    County  First Doubling  Last Delta   Inv Tau       Tau  \
# 276  Florida  Escambia               8          10  0.100598  9.940506
#
#      R Squared
# 276   0.742076
# Lake County
#        State County  First Doubling  Last Delta   Inv Tau        Tau  \
# 277  Florida   Lake               7           1  0.083631  11.957336
#
#      R Squared
# 277   0.733386
# Brevard County
#        State   County  First Doubling  Last Delta  Inv Tau       Tau  \
# 278  Florida  Brevard               9           6  0.10481  9.541057
#
#      R Squared
# 278   0.798552
# Polk County
#        State County  First Doubling  Last Delta   Inv Tau       Tau  R Squared
# 279  Florida   Polk               8          28  0.155818  6.417744   0.892119
# Walton County
# Empty DataFrame
# Columns: [State, County, First Doubling, Last Delta, Inv Tau, Tau, R Squared]
# Index: []
# Sumter County
#        State  County  First Doubling  Last Delta  Inv Tau        Tau  \
# 280  Florida  Sumter               6           9  0.04406  22.696568
#
#      R Squared
# 280   0.369555
# Leon County
#        State County  First Doubling  Last Delta   Inv Tau        Tau  \
# 281  Florida   Leon              12           6  0.057683  17.336142
#
#      R Squared
# 281    0.62174
# Martin County
#        State  County  First Doubling  Last Delta   Inv Tau        Tau  \
# 282  Florida  Martin               6           1  0.096891  10.320904
#
#      R Squared
# 282   0.621322
# Jackson County
# Empty DataFrame
# Columns: [State, County, First Doubling, Last Delta, Inv Tau, Tau, R Squared]
# Index: []
# Indian River County
#        State        County  First Doubling  Last Delta   Inv Tau        Tau  \
# 283  Florida  Indian River              10           3  0.074895  13.352051
#
#      R Squared
# 283   0.640203
# Hernando County
#        State    County  First Doubling  Last Delta   Inv Tau       Tau  \
# 284  Florida  Hernando              13           5  0.034884  28.66623
#
#      R Squared
# 284   0.453966
# Monroe County
#        State  County  First Doubling  Last Delta   Inv Tau        Tau  \
# 285  Florida  Monroe               5           1 -0.002659 -376.06367
#
#      R Squared
# 285   0.003307
# Marion County
#        State  County  First Doubling  Last Delta  Inv Tau        Tau  \
# 286  Florida  Marion               6           7  0.06388  15.654347
#
#      R Squared
# 286   0.600511
# Putnam County
# Empty DataFrame
# Columns: [State, County, First Doubling, Last Delta, Inv Tau, Tau, R Squared]
# Index: []
# Highlands County
# Empty DataFrame
# Columns: [State, County, First Doubling, Last Delta, Inv Tau, Tau, R Squared]
# Index: []
# Bay County
#        State County  First Doubling  Last Delta   Inv Tau        Tau  \
# 287  Florida    Bay              18           6 -0.015643 -63.925442
#
#      R Squared
# 287   0.140191
# St. Lucie County
#        State     County  First Doubling  Last Delta   Inv Tau       Tau  \
# 288  Florida  St. Lucie               6           8  0.134326  7.444559
#
#      R Squared
# 288   0.956301
# Unknown County
# Empty DataFrame
# Columns: [State, County, First Doubling, Last Delta, Inv Tau, Tau, R Squared]
# Index: []
# Bradford County
#        State    County  First Doubling  Last Delta   Inv Tau        Tau  \
# 289  Florida  Bradford              17           5 -0.029944 -33.395964
#
#      R Squared
# 289    0.23929
# Columbia County
# Empty DataFrame
# Columns: [State, County, First Doubling, Last Delta, Inv Tau, Tau, R Squared]
# Index: []
# Flagler County
#        State   County  First Doubling  Last Delta   Inv Tau         Tau  \
# 290  Florida  Flagler              17           5  0.008448  118.371273
#
#      R Squared
# 290   0.042194
# DeSoto County
# Empty DataFrame
# Columns: [State, County, First Doubling, Last Delta, Inv Tau, Tau, R Squared]
# Index: []
# Gadsden County
# Empty DataFrame
# Columns: [State, County, First Doubling, Last Delta, Inv Tau, Tau, R Squared]
# Index: []
# Washington County
# Empty DataFrame
# Columns: [State, County, First Doubling, Last Delta, Inv Tau, Tau, R Squared]
# Index: []
# Suwannee County
#        State    County  First Doubling  Last Delta   Inv Tau       Tau  \
# 291  Florida  Suwannee               7           7  0.128542  7.779566
#
#      R Squared
# 291    0.59633
# Levy County
# Empty DataFrame
# Columns: [State, County, First Doubling, Last Delta, Inv Tau, Tau, R Squared]
# Index: []
# Hendry County
# Empty DataFrame
# Columns: [State, County, First Doubling, Last Delta, Inv Tau, Tau, R Squared]
# Index: []
# Wakulla County
# Empty DataFrame
# Columns: [State, County, First Doubling, Last Delta, Inv Tau, Tau, R Squared]
# Index: []
# Glades County
# Empty DataFrame
# Columns: [State, County, First Doubling, Last Delta, Inv Tau, Tau, R Squared]
# Index: []
# Holmes County
# Empty DataFrame
# Columns: [State, County, First Doubling, Last Delta, Inv Tau, Tau, R Squared]
# Index: []
# Calhoun County
# Empty DataFrame
# Columns: [State, County, First Doubling, Last Delta, Inv Tau, Tau, R Squared]
# Index: []
# Union County
# Empty DataFrame
# Columns: [State, County, First Doubling, Last Delta, Inv Tau, Tau, R Squared]
# Index: []
# Madison County
# Empty DataFrame
# Columns: [State, County, First Doubling, Last Delta, Inv Tau, Tau, R Squared]
# Index: []
# Okeechobee County
# Empty DataFrame
# Columns: [State, County, First Doubling, Last Delta, Inv Tau, Tau, R Squared]
# Index: []
# Hardee County
# Empty DataFrame
# Columns: [State, County, First Doubling, Last Delta, Inv Tau, Tau, R Squared]
# Index: []
# Gulf County
# Empty DataFrame
# Columns: [State, County, First Doubling, Last Delta, Inv Tau, Tau, R Squared]
# Index: []
# Franklin County
# Empty DataFrame
# Columns: [State, County, First Doubling, Last Delta, Inv Tau, Tau, R Squared]
# Index: []
# Dixie County
# Empty DataFrame
# Columns: [State, County, First Doubling, Last Delta, Inv Tau, Tau, R Squared]
# Index: []
# Jefferson County
# Empty DataFrame
# Columns: [State, County, First Doubling, Last Delta, Inv Tau, Tau, R Squared]
# Index: []
# Hamilton County
# Empty DataFrame
# Columns: [State, County, First Doubling, Last Delta, Inv Tau, Tau, R Squared]
# Index: []
# Taylor County
# Empty DataFrame
# Columns: [State, County, First Doubling, Last Delta, Inv Tau, Tau, R Squared]
# Index: []
# Gilchrist County
# Empty DataFrame
# Columns: [State, County, First Doubling, Last Delta, Inv Tau, Tau, R Squared]
# Index: []
# Lafayette County
# Empty DataFrame
# Columns: [State, County, First Doubling, Last Delta, Inv Tau, Tau, R Squared]
# Index: []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-c369be87be23> in <module>
#       5     df4 = df2.loc[(df2['County']==x)&(df2['State']==state)]
#       6     print(df4)
# ----> 7     plt.plot(test[x]['xval'],test[x]['delta_cln3'])
#       8     plt.show()
#       9 #     time.sleep(5)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2794     return gca().plot(
#    2795         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2796         is not None else {}), **kwargs)
#    2797
#    2798
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
#    1667             self.add_line(line)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     389             x, y = index_of(tup[-1])
#     390
# --> 391         x, y = self._xy_from_xy(x, y)
#     392
#     393         if self.command == 'plot':
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in _xy_from_xy(self, x, y)
#     268         if x.shape[0] != y.shape[0]:
#     269             raise ValueError("x and y must have same first dimension, but "
# --> 270                              "have shapes {} and {}".format(x.shape, y.shape))
#     271         if x.ndim > 2 or y.ndim > 2:
#     272             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (2,) and (1,)
