# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
from scipy import stats

# %%
def regression (xnot,xxx,yyy):
    yval = [] 
    xval = [] 
    totdays = len(xxx) -1
    for days in range(xnot,totdays):
        xval.append(xxx[days]-xnot)
        yval.append(np.log(yyy[days]))
    (slope, intercept, r, a, b)=stats.linregress(xval, yval)
    return slope,r*r

# %%
data = pd.read_csv("https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv")
df = pd.DataFrame(data)
df.head()
# Out:
#          date     county       state     fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061.0      1       0
# 1  2020-01-22  Snohomish  Washington  53061.0      1       0
# 2  2020-01-23  Snohomish  Washington  53061.0      1       0
# 3  2020-01-24       Cook    Illinois  17031.0      1       0
# 4  2020-01-24  Snohomish  Washington  53061.0      1       0

# %%
df['date'] = pd.to_datetime(df['date'])
df.head()
counties = df['county'].value_counts()
states = df['state'].value_counts()
wake = df.loc[(df['state']=='North Carolina')& (df['county']=='Mecklenburg')]
wake.head(35)
# Out:
#             date       county           state     fips  cases  deaths
# 1532  2020-03-12  Mecklenburg  North Carolina  37119.0      2       0
# 1826  2020-03-13  Mecklenburg  North Carolina  37119.0      2       0
# 2180  2020-03-14  Mecklenburg  North Carolina  37119.0      2       0
# 2592  2020-03-15  Mecklenburg  North Carolina  37119.0      4       0
# 3054  2020-03-16  Mecklenburg  North Carolina  37119.0      4       0
# 3574  2020-03-17  Mecklenburg  North Carolina  37119.0      7       0
# 4181  2020-03-18  Mecklenburg  North Carolina  37119.0     11       0
# 4912  2020-03-19  Mecklenburg  North Carolina  37119.0     13       0
# 5766  2020-03-20  Mecklenburg  North Carolina  37119.0     28       0
# 6763  2020-03-21  Mecklenburg  North Carolina  37119.0     41       0
# 7865  2020-03-22  Mecklenburg  North Carolina  37119.0     66       0
# 9066  2020-03-23  Mecklenburg  North Carolina  37119.0     80       0
# 10379 2020-03-24  Mecklenburg  North Carolina  37119.0    104       0
# 11828 2020-03-25  Mecklenburg  North Carolina  37119.0    170       0
# 13441 2020-03-26  Mecklenburg  North Carolina  37119.0    181       0
# 15186 2020-03-27  Mecklenburg  North Carolina  37119.0    218       0
# 17028 2020-03-28  Mecklenburg  North Carolina  37119.0    299       0
# 18973 2020-03-29  Mecklenburg  North Carolina  37119.0    336       1
# 21023 2020-03-30  Mecklenburg  North Carolina  37119.0    382       1
# 23168 2020-03-31  Mecklenburg  North Carolina  37119.0    420       1
# 25372 2020-04-01  Mecklenburg  North Carolina  37119.0    444       2
# 27636 2020-04-02  Mecklenburg  North Carolina  37119.0    495       2
# 29962 2020-04-03  Mecklenburg  North Carolina  37119.0    564       2
# 32351 2020-04-04  Mecklenburg  North Carolina  37119.0    635       4
# 34784 2020-04-05  Mecklenburg  North Carolina  37119.0    664       6
# 37257 2020-04-06  Mecklenburg  North Carolina  37119.0    733       7
# 39770 2020-04-07  Mecklenburg  North Carolina  37119.0    810       8
# 42323 2020-04-08  Mecklenburg  North Carolina  37119.0    830      10

# %%
exponential={}
for st in states.index:
    state = df.loc[df['state']==st]
    counties = state['county'].value_counts()
    exponential.update( {st : {}} )
    for cnt in counties.index:
        county = state.loc[(df['county'] == cnt)]
        yprev = 0
        exponential[st].update({cnt:{}})
        exponential[st][cnt].update( {'xval' : []})
        exponential[st][cnt].update({'delta' :[]})
#         exponential[st][cnt].update({'date' :[]})
        days=0
        for y,z in county.iterrows(): 
            ycur = z['cases']
            dif = ycur - yprev
            exponential[st][cnt]['delta'].append(dif)
            exponential[st][cnt]['xval'].append(days)
#             exponential[st][cnt]['date'].append(z['date'])
            days=days+1
            yprev = ycur

# %%
for st in states.index:
    test = exponential[st]
    for cnt in test:
#     print(f'processing county {cnt}.')
#     print(f'X Val:{len(test[cnt]["xval"])} ')
        test[cnt].update({'delta_cln':[0]})
        if len(test[cnt]['delta']) > 2:
            for x in np.arange(1,len(test[cnt]['delta'])-1,1):
                test[cnt]['delta_cln'].append((test[cnt]['delta'][x-1]+test[cnt]['delta'][x]+test[cnt]['delta'][x+1])/3)
            test[cnt]['delta_cln'].append(test[cnt]['delta'][x+1])

# %%
for st in states.index:
    test = exponential[st]
    for cnt in test:
        test[cnt].update({'delta_cln2':[0]})
        if len(test[cnt]['delta']) > 2:
            for x in np.arange(1,len(test[cnt]['delta_cln'])-1,1):
                test[cnt]['delta_cln2'].append((test[cnt]['delta_cln'][x-1]+test[cnt]['delta_cln'][x]+test[cnt]['delta_cln'][x+1])/3)
            test[cnt]['delta_cln2'].append(test[cnt]['delta_cln'][x+1])

# %%
for st in states.index:
    test = exponential[st]
    for cnt in test:
        test[cnt].update({'delta_cln3':[0]})
        if len(test[cnt]['delta']) > 2:
            for x in np.arange(1,len(test[cnt]['delta_cln2'])-1,1):
                test[cnt]['delta_cln3'].append((test[cnt]['delta_cln2'][x-1]+test[cnt]['delta_cln2'][x]+test[cnt]['delta_cln2'][x+1])/3)
            test[cnt]['delta_cln3'].append(test[cnt]['delta_cln'][x+1])

# %%
county_tau = {'State':[],'County':[],'Days In':[],'Inv Tau':[],'R Squared':[]}
for st in states.index:
    test = exponential[st]
    for cnt in test:
        day=0
        test2 = test[cnt]
        for x in np.arange(1, len(test2['delta_cln3']),1):
            if test2['delta_cln3'][x]>4:
                day = x-1
                invtau,rr = regression(day,test2['xval'],test2['delta_cln3']) 
                county_tau['State'].append(st)
                county_tau['County'].append(cnt)
                county_tau['Days In'].append(day)
                county_tau['Inv Tau'].append(invtau)
                county_tau['R Squared'].append(rr)
                break
# Out:
# C:\Users\littl\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in log
#   import sys
# C:\Users\littl\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in log
#   import sys
# C:\Users\littl\Anaconda3\envs\PythonData\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# C:\Users\littl\Anaconda3\envs\PythonData\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# C:\Users\littl\Anaconda3\envs\PythonData\lib\site-packages\scipy\stats\_distn_infrastructure.py:1912: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# C:\Users\littl\Anaconda3\envs\PythonData\lib\site-packages\scipy\stats\_stats_mstats_common.py:130: RuntimeWarning: invalid value encountered in double_scalars
#   slope = r_num / ssxm
# C:\Users\littl\Anaconda3\envs\PythonData\lib\site-packages\scipy\stats\_stats_mstats_common.py:140: RuntimeWarning: invalid value encountered in sqrt
#   t = r * np.sqrt(df / ((1.0 - r + TINY)*(1.0 + r + TINY)))
# C:\Users\littl\Anaconda3\envs\PythonData\lib\site-packages\scipy\stats\_stats_mstats_common.py:142: RuntimeWarning: invalid value encountered in double_scalars
#   sterrest = np.sqrt((1 - r**2) * ssym / ssxm / df)
# C:\Users\littl\Anaconda3\envs\PythonData\lib\site-packages\numpy\lib\function_base.py:2449: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]

# %%
df2=pd.DataFrame(county_tau)
df2=df2.sort_values('Inv Tau', ascending =False)
df3 = df2.loc[df2['Inv Tau']>0]
df3.head(40)
# Out:
#               State             County  Days In   Inv Tau  R Squared
# 170  North Carolina              Moore       18  1.143540   0.992719
# 332        Kentucky         Muhlenberg       13  1.029619   1.000000
# 46          Georgia             Brooks        8  0.919793   1.000000
# 328        Kentucky            Pulaski       18  0.856652   1.000000
# 491       Minnesota          St. Louis       16  0.760451   1.000000
# 419        Illinois             Monroe       14  0.653926   1.000000
# 47          Georgia            Johnson        7  0.610455   1.000000
# 431        Missouri           Franklin       12  0.605855   0.999403
# 93         Virginia  Harrisonburg city       24  0.545917   1.000000
# 294        New York            Genesee       16  0.535389   0.999998
# 76            Texas              Comal       13  0.528844   1.000000
# 540          Kansas        Leavenworth       18  0.493593   0.992441
# 475            Iowa             Louisa        2  0.417399   0.984319
# 329        Kentucky          Christian       17  0.402707   0.999604
# 415        Illinois             DeKalb       16  0.374693   1.000000
# 174  North Carolina               Pitt       17  0.366104   1.000000
# 184  North Carolina         Rutherford        7  0.362905   1.000000
# 136         Indiana             Howard       26  0.351761   1.000000
# 585        Nebraska              Adams       18  0.349728   0.999999
# 633         Arizona             Apache       16  0.339868   1.000000
# 478        Arkansas            Garland       22  0.339216   1.000000
# 24          Georgia           Randolph       14  0.333016   0.833914
# 270         Florida          Highlands       16  0.325422   1.000000
# 83            Texas             Hardin       11  0.318288   0.966158
# 668        Delaware               Kent       12  0.317442   0.996471
# 25          Georgia               Tift       16  0.314304   0.999412
# 45          Georgia              Upson        8  0.310765   0.985919
# 119      California               Yolo       29  0.306125   0.985222
# 69            Texas              Ellis       20  0.301787   1.000000
# 578        Maryland          Frederick       14  0.299141   0.982421
# 43          Georgia               Ware       10  0.291179   0.949006
# 590   West Virginia          Jefferson       19  0.290103   0.999413
# 652     Connecticut         New London       12  0.287381   0.978781
# 583    South Dakota          Minnehaha       19  0.286052   0.997096
# 390       Louisiana         Tangipahoa        9  0.283065   0.888727
# 463         Alabama         Tallapoosa       13  0.282548   0.985480
# 38          Georgia             Pierce       13  0.277594   0.988008
# 362    Pennsylvania           Columbia       12  0.274665   0.992445
# 272         Florida           Suwannee        7  0.266167   0.994744
# 36          Georgia             Coffee       13  0.264466   0.834517

# %%
df3.plot('Days In','Inv Tau', kind ='scatter')

# %%
state = 'Georgia'
test =exponential[state]
for x in test:
     if len(test[x]['delta']) >2:
            plt.plot(test[x]['xval'],test[x]['delta'])
plt.show()

# %%
for x in test:
     if len(test[x]['delta']) >2:
            plt.plot(test[x]['xval'],test[x]['delta_cln'])
plt.show()

# %%
for x in test:
     if len(test[x]['delta']) >2:
            plt.plot(test[x]['xval'],test[x]['delta_cln2'])
plt.show()

# %%
for x in test:
     if len(test[x]['delta']) >2:
            plt.plot(test[x]['xval'],test[x]['delta_cln3'])
plt.show()

# %%
import keyboard
import time
for x in test:
    print(f'{x} County')
    df4 = df2.loc[(df2['County']==x)&(df2['State']==state)]
    print(df4)
    plt.plot(test[x]['xval'],test[x]['delta_cln3'])
    plt.show()
#     time.sleep(5)
# Out:
# Fulton County
#      State  County  Days In   Inv Tau  R Squared
# 0  Georgia  Fulton       11  0.127276   0.887943
# Polk County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Cobb County
#      State County  Days In   Inv Tau  R Squared
# 1  Georgia   Cobb        9  0.110863   0.914329
# Gwinnett County
#      State    County  Days In   Inv Tau  R Squared
# 2  Georgia  Gwinnett       11  0.139614    0.90719
# Cherokee County
#      State    County  Days In   Inv Tau  R Squared
# 3  Georgia  Cherokee       14  0.059028   0.803014
# Floyd County
#      State County  Days In   Inv Tau  R Squared
# 4  Georgia  Floyd       19 -0.056122   0.154643
# DeKalb County
#      State  County  Days In   Inv Tau  R Squared
# 5  Georgia  DeKalb        8  0.113759   0.825908
# Fayette County
#      State   County  Days In   Inv Tau  R Squared
# 6  Georgia  Fayette       17  0.029428    0.25359
# Charlton County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Lee County
#      State County  Days In   Inv Tau  R Squared
# 7  Georgia    Lee       14  0.115849   0.727473
# Lowndes County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Bartow County
#      State  County  Days In   Inv Tau  R Squared
# 8  Georgia  Bartow        5  0.008542   0.030712
# Henry County
#      State County  Days In   Inv Tau  R Squared
# 9  Georgia  Henry       10  0.094113   0.706448
# Gordon County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Coweta County
#       State  County  Days In   Inv Tau  R Squared
# 10  Georgia  Coweta       13  0.020368   0.129954
# Newton County
#       State  County  Days In   Inv Tau  R Squared
# 11  Georgia  Newton       14  0.010895   0.017661
# Clarke County
#       State  County  Days In   Inv Tau  R Squared
# 12  Georgia  Clarke        9 -0.008096   0.045651
# Dougherty County
#       State     County  Days In   Inv Tau  R Squared
# 13  Georgia  Dougherty        2  0.129389   0.864786
# Clayton County
#       State   County  Days In   Inv Tau  R Squared
# 14  Georgia  Clayton        8  0.108977   0.617176
# Troup County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Forsyth County
#       State   County  Days In   Inv Tau  R Squared
# 15  Georgia  Forsyth       10  0.035758   0.329293
# Hall County
#       State County  Days In   Inv Tau  R Squared
# 16  Georgia   Hall        9  0.167735   0.961721
# Paulding County
#       State    County  Days In   Inv Tau  R Squared
# 17  Georgia  Paulding       11  0.011111   0.170072
# Richmond County
#       State    County  Days In   Inv Tau  R Squared
# 18  Georgia  Richmond       12 -0.012164   0.016801
# Whitfield County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Houston County
#       State   County  Days In   Inv Tau  R Squared
# 19  Georgia  Houston       10  0.068804   0.464829
# Columbia County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Early County
#       State County  Days In   Inv Tau  R Squared
# 20  Georgia  Early       10  0.059672    0.32551
# Laurens County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Rockdale County
#       State    County  Days In   Inv Tau  R Squared
# 21  Georgia  Rockdale        9 -0.065622   0.159753
# Glynn County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Peach County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Effingham County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Bibb County
#       State County  Days In   Inv Tau  R Squared
# 22  Georgia   Bibb       13  0.007909   0.050926
# Sumter County
#       State  County  Days In   Inv Tau  R Squared
# 23  Georgia  Sumter        8  0.186055   0.951324
# Randolph County
#       State    County  Days In   Inv Tau  R Squared
# 24  Georgia  Randolph       14  0.333016   0.833914
# Heard County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Tift County
#       State County  Days In   Inv Tau  R Squared
# 25  Georgia   Tift       16  0.314304   0.999412
# Pickens County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Lamar County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Dawson County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Spalding County
#       State    County  Days In   Inv Tau  R Squared
# 26  Georgia  Spalding       14  0.176863   0.670707
# Carroll County
#       State   County  Days In   Inv Tau  R Squared
# 27  Georgia  Carroll        2  0.003333   0.001785
# Chatham County
#       State   County  Days In   Inv Tau  R Squared
# 28  Georgia  Chatham        9  0.120492   0.583193
# Muscogee County
#       State    County  Days In   Inv Tau  R Squared
# 29  Georgia  Muscogee       11  0.237476   0.750668
# Terrell County
#       State   County  Days In   Inv Tau  R Squared
# 30  Georgia  Terrell        8  0.029879   0.094742
# Douglas County
#       State   County  Days In   Inv Tau  R Squared
# 31  Georgia  Douglas        4  0.062411    0.90428
# Lincoln County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Oconee County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Unknown County
#       State   County  Days In  Inv Tau  R Squared
# 32  Georgia  Unknown        0      NaN        NaN
# Miller County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Monroe County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Turner County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Worth County
#       State County  Days In   Inv Tau  R Squared
# 33  Georgia  Worth        9  0.037226   0.150192
# Lumpkin County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Baldwin County
#       State   County  Days In   Inv Tau  R Squared
# 34  Georgia  Baldwin       15  0.064767   0.469161
# Twiggs County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Barrow County
#       State  County  Days In   Inv Tau  R Squared
# 35  Georgia  Barrow       14  0.182169     0.8601
# Coffee County
#       State  County  Days In   Inv Tau  R Squared
# 36  Georgia  Coffee       13  0.264466   0.834517
# Chattooga County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Butts County
#       State County  Days In  Inv Tau  R Squared
# 37  Georgia  Butts       16      NaN        0.0
# Clinch County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Tattnall County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Burke County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Liberty County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Catoosa County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Madison County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Pierce County
#       State  County  Days In   Inv Tau  R Squared
# 38  Georgia  Pierce       13  0.277594   0.988008
# Harris County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Washington County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Morgan County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Mitchell County
#       State    County  Days In   Inv Tau  R Squared
# 39  Georgia  Mitchell        5  0.123638   0.740891
# Fannin County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Crisp County
#       State County  Days In   Inv Tau  R Squared
# 40  Georgia  Crisp       10  0.177031   0.935911
# Pulaski County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Colquitt County
#       State    County  Days In   Inv Tau  R Squared
# 41  Georgia  Colquitt        6  0.071276   0.595705
# Stephens County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Ben Hill County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Irwin County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Baker County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Jasper County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Greene County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Bryan County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Seminole County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Meriwether County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Camden County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Macon County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Jones County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Dodge County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Long County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Wilkes County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Jackson County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Walton County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Decatur County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Taylor County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# White County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Thomas County
#       State  County  Days In   Inv Tau  R Squared
# 42  Georgia  Thomas        7  0.138155   0.607496
# Ware County
#       State County  Days In   Inv Tau  R Squared
# 43  Georgia   Ware       10  0.291179   0.949006
# Toombs County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Haralson County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Franklin County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# McDuffie County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Calhoun County
#       State   County  Days In   Inv Tau  R Squared
# 44  Georgia  Calhoun       10  0.131983   0.840835
# Hart County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Upson County
#       State County  Days In   Inv Tau  R Squared
# 45  Georgia  Upson        8  0.310765   0.985919
# Chattahoochee County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Wheeler County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Bulloch County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Jenkins County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Pike County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Murray County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Habersham County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Brooks County
#       State  County  Days In   Inv Tau  R Squared
# 46  Georgia  Brooks        8  0.919793        1.0
# Candler County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Bacon County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Clay County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Dooly County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Johnson County
#       State   County  Days In   Inv Tau  R Squared
# 47  Georgia  Johnson        7  0.610455        1.0
# Jefferson County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Bleckley County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Berrien County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Warren County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Gilmer County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# McIntosh County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Cook County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Schley County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Banks County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Dade County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Appling County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Talbot County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Telfair County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Wilcox County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Screven County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Rabun County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Walker County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Emanuel County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Grady County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Oglethorpe County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Wilkinson County
#       State     County  Days In  Inv Tau  R Squared
# 48  Georgia  Wilkinson        7      NaN        0.0
# Webster County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Stewart County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Union County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Putnam County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Lanier County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Jeff Davis County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Elbert County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Quitman County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Marion County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Towns County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Wayne County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Crawford County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Brantley County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Atkinson County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Treutlen County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Echols County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# Hancock County
# Empty DataFrame
# Columns: [State, County, Days In, Inv Tau, R Squared]
# Index: []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-c369be87be23> in <module>
#       5     df4 = df2.loc[(df2['County']==x)&(df2['State']==state)]
#       6     print(df4)
# ----> 7     plt.plot(test[x]['xval'],test[x]['delta_cln3'])
#       8     plt.show()
#       9 #     time.sleep(5)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2794     return gca().plot(
#    2795         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2796         is not None else {}), **kwargs)
#    2797
#    2798
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
#    1667             self.add_line(line)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     389             x, y = index_of(tup[-1])
#     390
# --> 391         x, y = self._xy_from_xy(x, y)
#     392
#     393         if self.command == 'plot':
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in _xy_from_xy(self, x, y)
#     268         if x.shape[0] != y.shape[0]:
#     269             raise ValueError("x and y must have same first dimension, but "
# --> 270                              "have shapes {} and {}".format(x.shape, y.shape))
#     271         if x.ndim > 2 or y.ndim > 2:
#     272             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (2,) and (1,)
